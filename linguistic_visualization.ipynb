# %% [markdown]
# # Case Study by Linguistic Features Visualization
#
#
# This notebook is to visualize important linguistic features in the NPS prediction model and perform the case study to provide suggestions for unpopular courses.

# %% [markdown]
# ## 1. Import Packages

# %%
import pandas as pd
import numpy as np
import zipfile
import os
import collections
from collections import defaultdict
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
! pip install pysrt
import matplotlib.pyplot as plt
# !pip install textatistic
from textatistic import Textatistic
from matplotlib.pyplot import figure
import pysrt
! pip install sentence_transformers
from sentence_transformers import SentenceTransformer
import spacy
from scipy import spatial
# Out:
# Requirement already satisfied: pysrt in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: chardet in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from pysrt) (4.0.0)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/qichao/opt/miniconda3/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: textatistic in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: pyhyphen>=2.0.5 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from textatistic) (4.0.3)
# Requirement already satisfied: requests>=2.25 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from pyhyphen>=2.0.5->textatistic) (2.27.1)
# Requirement already satisfied: appdirs>=1.4.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from pyhyphen>=2.0.5->textatistic) (1.4.4)
# Requirement already satisfied: wheel>=0.36.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from pyhyphen>=2.0.5->textatistic) (0.37.1)
# Requirement already satisfied: setuptools>=52.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from pyhyphen>=2.0.5->textatistic) (60.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.25->pyhyphen>=2.0.5->textatistic) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.25->pyhyphen>=2.0.5->textatistic) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.25->pyhyphen>=2.0.5->textatistic) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.25->pyhyphen>=2.0.5->textatistic) (3.1)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/qichao/opt/miniconda3/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: sentence_transformers in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: torchvision in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (0.11.2)
# Requirement already satisfied: sentencepiece in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (0.1.96)
# Requirement already satisfied: nltk in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (3.5)
# Requirement already satisfied: torch>=1.6.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: numpy in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (1.21.2)
# Requirement already satisfied: scikit-learn in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: huggingface-hub in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (0.4.0)
# Requirement already satisfied: scipy in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (1.7.1)
# Requirement already satisfied: tqdm in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sentence_transformers) (4.16.2)
# Requirement already satisfied: typing_extensions in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Requirement already satisfied: sacremoses in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.47)
# Requirement already satisfied: filelock in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.11.10)
# Requirement already satisfied: pyyaml>=5.1 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (5.4.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.11.5)
# Requirement already satisfied: requests in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.0)
# Requirement already satisfied: click in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from nltk->sentence_transformers) (8.0.1)
# Requirement already satisfied: joblib in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from nltk->sentence_transformers) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from torchvision->sentence_transformers) (8.3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: six in /Users/qichao/opt/miniconda3/lib/python3.9/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/qichao/opt/miniconda3/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## 2. Import Data
#
# Import the survey data (`'EndOfCourseSurvey.csv'`) and the course transcript data from zip file (`'SRT files-20220429T000407Z-001.zip'`).

# %% [markdown]
# ### 2.1. Survey Data

# %%
df = pd.read_csv('EndOfCourseSurvey.csv')
df.head()
# Out:
# /Users/qichao/opt/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    FactId                DateCompleted  \
# 0  142055  2021-07-07 12:28:00.0000000
# 1  142056  2021-08-12 14:42:00.0000000
# 2  142057  2021-08-18 03:46:00.0000000
# 3  142058  2021-08-22 16:34:00.0000000
# 4  142059  2021-08-25 01:48:00.0000000
#
#                                           Question_1  Response_Q1  \
# 0  How likely is it that you would recommend this...            9
# 1  How likely is it that you would recommend this...            9
# 2  How likely is it that you would recommend this...           10
# 3  How likely is it that you would recommend this...           10
# 4  How likely is it that you would recommend this...           10
#
#                                           Question_2     Response_Q2  \
# 0  This course covered the topics and content tha...           Agree
# 1  This course covered the topics and content tha...           Agree
# 2  This course covered the topics and content tha...  Strongly Agree
# 3  This course covered the topics and content tha...  Strongly Agree
# 4  This course covered the topics and content tha...  Strongly Agree
#
#                                           Question_3     Response_Q3  \
# 0  The course materials were engaging, clear, and...           Agree
# 1  The course materials were engaging, clear, and...           Agree
# 2  The course materials were engaging, clear, and...  Strongly Agree
# 3  The course materials were engaging, clear, and...  Strongly Agree
# 4  The course materials were engaging, clear, and...  Strongly Agree
#
#                                           Question_4     Response_Q4  ...  \
# 0  The instructor was effective in delivering the...           Agree  ...
# 1  The instructor was effective in delivering the...           Agree  ...
# 2  The instructor was effective in delivering the...  Strongly Agree  ...
# 3  The instructor was effective in delivering the...  Strongly Agree  ...
# 4  The instructor was effective in delivering the...  Strongly Agree  ...
#
#        Response_Q5 CustomerID                              CourseName  \
# 0  Did Not Respond     198151  Building a 3 Statement Financial Model
# 1  Did Not Respond     152550  Building a 3 Statement Financial Model
# 2  Did Not Respond     191851  Building a 3 Statement Financial Model
# 3  Did Not Respond     263617  Building a 3 Statement Financial Model
# 4  Did Not Respond     305095  Building a 3 Statement Financial Model
#
#    Instructor Program Requirement Level VideoLenght  Price  SurveyType
# 0  Tim Vipond    FMVA        Core     3     2-3 hrs  197.0   NewSurvey
# 1  Tim Vipond    FMVA        Core     3     2-3 hrs  197.0   NewSurvey
# 2  Tim Vipond    FMVA        Core     3     2-3 hrs  197.0   NewSurvey
# 3  Tim Vipond    FMVA        Core     3     2-3 hrs  197.0   NewSurvey
# 4  Tim Vipond    FMVA        Core     3     2-3 hrs  197.0   NewSurvey
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.2. Transcript Data

# %% [markdown]
# #### 2.2.1. Feature Extraction

# %% [markdown]
# The pipeline below is to import the transcript text data and extract the important linguistic features to store them in dictionaries.
# The `try-except` syntax is to skip the un-decodable srt files which are proven to be empty.
#
# - The features are stored as the following format:
#
# {`'course_name_1'`: {`'video_1'`: `feature_value`,
#                     `'video_2'`: `feature_value`,
#                     ...
#                     ...}
#
# `'course_name_2'`: {`'video_1'`: `feature_value`,
#                     `'video_2'`: `feature_value`,
#                     ...
#                     ...}
#
# ...
#
# ...
#
#
# }

# %%
zip_file = zipfile.ZipFile('SRT files-20220429T000407Z-001.zip', 'r')
files = zip_file.infolist()

duration_dict = defaultdict(dict)
text_dict = defaultdict(dict)
word_count = defaultdict(dict)
word_per_second = defaultdict(dict)
flesch_score = defaultdict(dict)

for i in range(len(zip_file.infolist())):

    try:
        chapter_text = ''
        chapter_duration = pysrt.srttime.SubRipTime()
        #print(chapter_duration)
        filename = files[i].filename
        path_to_extracted_file = zip_file.extract(filename)
        course_name = filename.split('/')[1]
        #print(course_name)
        section_name = filename
        #print(section_name)
        subs = pysrt.open(path_to_extracted_file)
        

        for j in range(len(subs)):
            sub = subs[j]
            course_text = sub.text + ' '
            duration = sub.duration
            chapter_duration += duration
            chapter_text += course_text
            chapter_seconds = chapter_duration.milliseconds/1000 + chapter_duration.seconds + chapter_duration.minutes*60 + chapter_duration.hours*3600
            
        duration_dict[course_name][section_name] = chapter_seconds
        text_dict[course_name][section_name] = chapter_text
        
        w_count = len(tokenizer.tokenize(chapter_text))
        word_count[course_name][section_name] = w_count
        word_per_second[course_name][section_name] = w_count/chapter_seconds
        flesch = Textatistic(chapter_text).scores['flesch_score']
        flesch_score[course_name][section_name] = flesch
    
    except:
        pass

# %% [markdown]
# Have a look at the duration feature of course `'Rocky Mountain Holdings Limited Case Study'`:

# %%
duration_dict['Rocky Mountain Holdings Limited Case Study']
# Out:
# {'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_11_Analysis Tab.srt': 74.92,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_19_Summary.srt': 63.92,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_14_Debrief - Analysis Tab Interpretation.srt': 186.32,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_16_Debrief - Risk Rating and Pricing.srt': 170.52,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_10_Debreif - Rent Roll Tab.srt': 135.645,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_09_Rent Roll Tab.srt': 37.48,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_13_Debrief - Analysis Tab Expenses.srt': 185.14,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_18_Debrief - Discussion Paper.srt': 354.061,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_06_Debrief - Timeline.srt': 145.41,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_15_Risk Rating and Pricing.srt': 115.36,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_17_Discussion Paper.srt': 54.36,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_03_Case Background.srt': 252.66,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_05_Debrief - Appraisal and Checklist.srt': 378.48,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_07_Debrief - Offer to Lease.srt': 291.421,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_04_Debrief - Purchase and Sale Agreement.srt': 297.54,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_01_Introduction.srt': 94.03999999999999,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_08_Timeline to Completion.srt': 90.98,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_12_Debrief - Analysis Tab Inputs.srt': 93.27000000000001,
#  'SRT files/Rocky Mountain Holdings Limited Case Study/RockyMountainLtd_02_Document and Resource Checklist.srt': 99.82}

# %% [markdown]
# #### 2.2.1. Data Transformation

# %% [markdown]
# The video name are not well sorted. the function below is to sort the videos in each course by their name:

# %%
def sort_dicts_in_dict(dictionary):

    '''sort the dictionaries in a dictionary by the keys'''
    
    for (course_name, course_transcript) in dictionary.items():
        sorted_course_transcript = sorted(course_transcript.items())
        dictionary[course_name] = list(dict(sorted_course_transcript).values())
        
    return dictionary

# %% [markdown]
# Apply the function to the duration feature dictionary:

# %%
duration_dict = sort_dicts_in_dict(duration_dict)

# %%
duration_dict['Rocky Mountain Holdings Limited Case Study']
# Out:
# [94.03999999999999,
#  99.82,
#  252.66,
#  297.54,
#  378.48,
#  145.41,
#  291.421,
#  90.98,
#  37.48,
#  135.645,
#  74.92,
#  93.27000000000001,
#  185.14,
#  186.32,
#  115.36,
#  170.52,
#  54.36,
#  354.061,
#  63.92]

# %% [markdown]
# Now the feature values are well sorted from video 1 to video 19. We don't need the video name as the key any more. The feature values are stored in a list to be further transformed into columns in a data frame.

# %% [markdown]
# We can apply the function to the rest of the dictionaries.

# %%
text_dict = sort_dicts_in_dict(text_dict)
word_count = sort_dicts_in_dict(word_count)
word_per_second = sort_dicts_in_dict(word_per_second)
flesch_score = sort_dicts_in_dict(flesch_score)

# %% [markdown]
# The dictionaries can be converted into data frames for merging and visualization.

# %%
duration_df = pd.DataFrame(duration_dict.items(), columns=['CourseName', 'Duration'])
transcript_df = pd.DataFrame(text_dict.items(), columns=['CourseName', 'Transcript'])
word_count_df = pd.DataFrame(word_count.items(), columns=['CourseName', 'word_count'])
word_per_second_df = pd.DataFrame(word_per_second.items(), columns=['CourseName', 'word_per_second'])
flesch_score_df = pd.DataFrame(flesch_score.items(), columns=['CourseName', 'flesch_score'])

# %%
duration_df
# Out:
#                                      CourseName  \
# 0    Rocky Mountain Holdings Limited Case Study
# 1              Refinitiv Workspace Fundamentals
# 2                      Vertical IQ Fundamentals
# 3      Scenario _ Sensitivity Analysis in Excel
# 4                       Statistics Fundamentals
# ..                                          ...
# 127     Credit Administration and Documentation
# 128                Equity, FX, and Rate Futures
# 129          Commercial Banking - Debt Modeling
# 130                              Loan Covenants
# 131                               Loan Security
#
#                                               Duration
# 0    [94.03999999999999, 99.82, 252.66, 297.54, 378...
# 1    [47.03, 70.26, 84.17, 103.38, 110.460000000000...
# 2    [95.84, 152.127, 42.04, 196.77, 118.08, 196.10...
# 3    [101.22, 51.39, 90.66, 61.4, 106.5099999999999...
# 4    [110.50999999999999, 103.74000000000001, 51.96...
# ..                                                 ...
# 127  [100.22999999999999, 105.62299999999999, 76.82...
# 128  [12.42, 104.47999999999999, 107.779, 116.24000...
# 129  [63.18, 118.93, 160.32, 156.76, 91.58, 70.11, ...
# 130  [125.96, 120.79, 75.28, 104.328, 93.16, 142.07...
# 131  [104.28, 83.53999999999999, 162.5, 106.2700000...
#
# [132 rows x 2 columns]

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# **For collaboration purpose, The data transformation and processing are performed in google Colab. So the transformed data can be used directly in the file.**

# %% [markdown]
# # Import data
#
# The `chapter_nps_df_120` data frame contains 120 validated courses data. Each row represent one video of a course.

# %%
import pandas as pd
import altair as alt

# %%
chapter_nps_df_120 = pd.read_csv("chapter_nps_df_120.csv")

# %%
chapter_nps_df_120.head()
# Out:
#    Unnamed: 0                                  CourseName  \
# 0           0  Rocky Mountain Holdings Limited Case Study
# 1           1  Rocky Mountain Holdings Limited Case Study
# 2           2  Rocky Mountain Holdings Limited Case Study
# 3           3  Rocky Mountain Holdings Limited Case Study
# 4           4  Rocky Mountain Holdings Limited Case Study
#
#                                           Transcript  Response_Q1  Duration  \
# 0  Hi. I'm Kyle Peterdy, VP, commercial credit an...      9.14554     94.04
# 1  Please ensure that your due diligence package ...      9.14554     99.82
# 2  Before we get into the due diligence package, ...      9.14554    252.66
# 3  Many of the line items in a purchase and sale ...      9.14554    297.54
# 4  First, let's add to our timeline. The appraisa...      9.14554    378.48
#
#                                          ChapterName  Chapter_count  \
# 0  SRT files/Rocky Mountain Holdings Limited Case...             19
# 1  SRT files/Rocky Mountain Holdings Limited Case...             19
# 2  SRT files/Rocky Mountain Holdings Limited Case...             19
# 3  SRT files/Rocky Mountain Holdings Limited Case...             19
# 4  SRT files/Rocky Mountain Holdings Limited Case...             19
#
#    word_count  sent_count  avg_sentence_length  ...  Program_x  Requirement_x  \
# 0         262          12            21.833333  ...        CRE     Case Study
# 1         276          14            19.714286  ...        CRE     Case Study
# 2         660          29            22.758621  ...        CRE     Case Study
# 3         818          44            18.590909  ...        CRE     Case Study
# 4        1011          49            20.632653  ...        CRE     Case Study
#
#    Level_x  VideoLenght_x  Price_x  Program_y  Requirement_y  Level_y  \
# 0        4     Under 1 hr    147.0        CRE     Case Study        4
# 1        4     Under 1 hr    147.0        CRE     Case Study        4
# 2        4     Under 1 hr    147.0        CRE     Case Study        4
# 3        4     Under 1 hr    147.0        CRE     Case Study        4
# 4        4     Under 1 hr    147.0        CRE     Case Study        4
#
#    VideoLenght_y  Price_y
# 0     Under 1 hr    147.0
# 1     Under 1 hr    147.0
# 2     Under 1 hr    147.0
# 3     Under 1 hr    147.0
# 4     Under 1 hr    147.0
#
# [5 rows x 34 columns]

# %% [markdown]
# These are the columns of the data frame. they are used to train the Machine Learning models in another file.
#
# Here we only used the `word_per_second`(speech speed), `flesch_reading_ease` and `avg_coherence` for visualization.

# %%
chapter_nps_df_120.columns
# Out:
# Index(['Unnamed: 0', 'CourseName', 'Transcript', 'Response_Q1', 'Duration',
#        'ChapterName', 'Chapter_count', 'word_count', 'sent_count',
#        'avg_sentence_length', 'avg_syllables_per_word', 'difficult_words',
#        'verb_count', 'nnp_count', 'nn_count', 'adverb_count', 'ner_count',
#        'flesch_reading_ease', 'gunning_fog', 'smog_index',
#        'dale_chall_readability_score', 'avg_coherence', 'word_per_second',
#        'NPS_score', 'Program_x', 'Requirement_x', 'Level_x', 'VideoLenght_x',
#        'Price_x', 'Program_y', 'Requirement_y', 'Level_y', 'VideoLenght_y',
#        'Price_y'],
#       dtype='object')

# %% [markdown]
# These 3 columns are added for visualization legends:

# %%
chapter_nps_df_120["speed"] = "Speed (words/sec)"
chapter_nps_df_120["coherence"] = "Coherence"
chapter_nps_df_120["readability"] = "Readability"

# %% [markdown]
# The function below is for the final visualization. We can modify the

# %%
def viz_lines(CourseName):
    '''For a input course name,
    visualize the overlapping line graphs 
    of speed, readability and coherence by pairs'''
    course_df = chapter_nps_df_120[chapter_nps_df_120["CourseName"] == CourseName]
    course_df['Section'] = range(1, len(course_df)+1)
    #Title = str(CourseName) + "(NPS:{})".format(course_df['Response_Q1'][0])

    speed = alt.Chart(course_df, title=CourseName).mark_line(color='red').encode(
        x=alt.X('Section', axis=alt.Axis(tickCount=course_df.shape[0], title="Section")),
        y=alt.Y('word_per_second', axis=alt.Axis(title='', titleColor='red')),
        opacity=alt.Opacity('speed', legend=alt.Legend(title=""))
    ).properties(
    width=1000
    )
    

    readability = alt.Chart(course_df).mark_line(color='green').encode(
        x=alt.X('Section', axis=alt.Axis(title="Section")),
        y=alt.Y('flesch_reading_ease', axis=alt.Axis(title='', titleColor='green')),
        opacity=alt.Opacity('readability', legend=alt.Legend(title=""))
    ).properties(
        width=1000
    )

    
    coherence = alt.Chart(course_df).mark_line(color='blue').encode(
        x=alt.X('Section', axis=alt.Axis(title="Section")),
        y=alt.Y('avg_coherence', axis=alt.Axis(title='', titleColor='blue',ticks=False,labels=False)),
        opacity=alt.Opacity('coherence', legend=alt.Legend(title=""))
    ).properties(
        width=1000
    )
    

    
    graph = alt.layer(speed, coherence, readability).resolve_scale(
        y = 'independent',
        opacity='independent'
    )

    return graph

# %%
viz_lines("Introduction to ESG")
# Out:
# /var/folders/3z/vln54yld7pl4fbx7dy7pfg580000gp/T/ipykernel_74166/3598757986.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_df['Section'] = range(1, len(course_df)+1)
# alt.LayerChart(...)

# %%
viz_lines("ESG Disclosure")
# Lowest NPS score
# Out:
# /var/folders/3z/vln54yld7pl4fbx7dy7pfg580000gp/T/ipykernel_74166/3598757986.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_df['Section'] = range(1, len(course_df)+1)
# alt.LayerChart(...)

# %%
viz_lines("Case Study - RockCrusher Rentals")
# Highest NPS score 9.25
# Out:
# /var/folders/3z/vln54yld7pl4fbx7dy7pfg580000gp/T/ipykernel_74166/3598757986.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_df['Section'] = range(1, len(course_df)+1)
# alt.LayerChart(...)

# %% [markdown]
# <br><br><br><br><br><br><br><br>
